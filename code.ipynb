# %% [markdown]
# 1. 버거지수를 활용한 지역별 발전정도 확인
# 2. 한 도시의 발전 수준은 '(버거킹수 + 맥도날드수 + KFC수)/롯데리아수'로 계산
# 3. 높게 나올 수록 더 많이 발전된 도시

# %%
# 초기 다운 라이브러리
# !pip install koreanize-matplotlib   # 한글폰트 지원도구
# !pip install seaborn                # 데이터 시각화

import pandas as pd
import seaborn as sns 
import koreanize_matplotlib
import matplotlib.pyplot as plt
from glob import glob               # 여러개의 파일을 쉽게 불러오기 위한 도구
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'

# %%
# 반복문을 사용하여 전체 파일 업로드
file_names = glob("*.csv")          
df_list = []
for file_path in file_names:
    df_temp = pd.read_csv(file_path, low_memory=False)     # False -> 데이터 타입이 섞여 있는 경우 경고
    df_list.append(df_temp)

# %%
# concat을 통해 하나의 데이터 프레임으로 합치기
df = pd.concat(df_list)

# %%
# 전처리
df = df[{'상호명', '상권업종대분류명', '시도명', '시군구명', '도로명주소', '경도', '위도'}].copy()  # 필요한 컬럼 남기기
df = df[df["상호명"].notnull()].copy()
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_12688\1143960995.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = df[{'상호명', '상권업종대분류명', '시도명', '시군구명', '도로명주소', '경도', '위도'}].copy()  # 필요한 컬럼 남기기

# %%
# 상호명이 없는 데이터 제거
df = df[df["상호명"].notnull()].copy()

# %%
# 상호명을 대문자로 변경
df["상호명_대문자"] = df["상호명"].str.upper()

# %%
# BMKL(버거킹,맥도날드,KFC,롯데리아) 추출
burger = ["버거킹", "맥도날드", "KFC", "롯데리아"]
df = df[df["상호명_대문자"].str.contains("버거킹|Burger|맥도날드|멕도날드|롯데리아|KFC|케이에프씨")]

# %%
# 전처리를 위한 유일값 확인
df["상호명"].unique()
# Out:
# array(['버거킹', '롯데리아', '케이에프씨원주단계', '맥도날드', 'KFC원주단계DT점', '케이에프씨춘천석사',
#        'KFC', '롯데리아문막휴게소강릉방면', 'BKR버거킹', '문막휴게소롯데리아', '맥도날드동해DT점',
#        'KFC춘천이마트점', '버거킹춘천거두GS점', '케이에프씨춘천이마트', '한국맥도날드춘천후평DT점춘천후평DT점',
#        '롯데리아고성간성점', '에스알에스KFC현대성우', '롯데리아익스프레스점', '한국맥도날드강릉올림픽파크레스토랑점',
#        '롯데리아혁신도시점', '에이치케이라온롯데리아롯데마트', '신맥맥도날드원주', '롯데리아원주일산점',
#        '문막휴게소강릉방향롯데리아', '한국맥도날드춘천후평DT점', '한국맥도날드원주단계DT', '한국맥도날드춘천퇴계DT점',
#        '버거킹오션월드', '하나로마트롯데리아', '맥도날드이천점', '롯데리아여주휴게소인천방면', '용인보정KFC',
#        '맥도날드마석점', '버거킹여주휴게소강릉방면', 'KFC서현역점', '롯데리아산본중앙', '용인상현KFC',
#        '맥도날드수원세류DT점', 'KFC정자역점정자역점', 'KFC야탑역점', '맥도날드이천아미점', '롯데리아호원점',
#        'KFC용인명지DT점', '롯데리아수원연무점', '버거킹평택서정점', 'SRSKFC수원역사', 'SRSKFC부천역',
#        'SRSKFC분당월드쇼핑', 'SRSKFC', '롯데리아경기대역점', 'SRSKFC서현역', 'SRSKFC영통시네마',
#        '롯데리아일산가좌점', '세이브존롯데리아', 'KFC이천터미널', '맥도날드고양원당DT점', '대민롯데리아',
#        '맥도날드용인동백DT점', '롯데리아화성봉담점', '롯데리아가평현리점', '롯데리아오산세교디티',
#        '한국맥도날드화성봉담DT점', 'KFC하남홈플러스점', '롯데리아자유로휴게소점', '버거킹동두천DT',
#        'KFC용인보정점', 'KFC오산DT점', 'KFC용인상현점', 'KFC동탄점', '맥도날드구리수택점',
#        '버거킹오산궐동점', 'KFC수원인계DT점', 'BKR버거킹분당서현점', '롯데리아여주가남점', '롯데리아김포장기점',
#        '롯데리아여주375아울렛', 'kfc', 'KFC베어스타운점', '한국맥도날드수원정자DT점', '버거킹용인신갈점',
#        '한국맥도날드이천DT점', '맥도날드의정부만가대DT점', '한국맥도날드광명DT점', '롯데리아더푸드하우스',
#        '한국맥도날드김포감정DT', '버거킹안산상록수역점', 'KFC김포장기점', '케이에프씨오산디티매장', 'KFC아주대점',
#        '롯데리아안양석수DT점', '롯데리아SERVICE', '롯데리아향남2신도시점', '맥도날드소사벌점', '롯데리아낙양점',
#        '롯데리아상록수점', '롯데리아평내점', '맥도날드용인신갈DT점', '신화관광개발롯데리아', '버거킹수원영통점',
#        '롯데리아의정부민락점', '버거킹경기양평점', '롯데리아송파점', '우림개발용인상휴게소롯데리아',
#        '케이에프씨수원역사1매장', '롯데리아회룡역점', '맥도날드동수원GSDT점', '롯데리아375아울렛',
#        '한국맥도날드수원인계DT', 'KFC김포한강', '한국맥도날드고양풍동DT점고양풍동DT점', '화경롯데리아여주점',
#        '롯데리아수원삼성전자점', 'BKR버거킹서수원이마트', 'BKR버거킹분당상록점', 'BKR버거킹의정부점',
#        'BKR버거킹죽전SK점', 'BKR버거킹아주대병원점', '신맥한국맥도날드', '버거킹평촌금성GS', '롯데리아뱃놀이',
#        '한국맥도날드양주휴게소DT점', '롯데리아용인터미널', '롯데리아T.G.I.F분', '케이에프씨일산후곡',
#        '한국맥도날드수원아주', '한국맥도날드오산세교DT', '롯데리아T.G.I.F안', '롯데리아용인상현점',
#        '롯데리아중동인성', '한국맥도날드과천', '롯데리아엔터점', '시흥하늘휴게소롯데리아', '맥도날드의왕오전DT점',
#        '에스알에스KFC', '에스알에스KFC베어스타', '우림개발용인하휴게소맥도날드', '한국맥도날드용인시청DT점',
#        '버거킹구리', '한국맥도날드오산세교DT점', '롯데리아고양행신역', '정자역케이에프씨', '한국맥도날드용인',
#        '한국맥도날드부천원종DT점', '롯데리아광교드라이브점', '신흥맥도날드', '버거킹이천CGV점',
#        '맥도날드화성향남DT점', '롯데리아양주덕정점', '롯데리아크리스피크림동', '제이에스엠맥도날드동탄S',
#        '롯데리아크리스피크림도', '한국맥도날드의정부녹양DT', 'KFC용인명지DT', '맥도날드용인신갈DT',
#        '에스알에스코리아KFC수', '한국맥도날드수원성균관대', '디케이에프씨', '롯데리아파주교하점', 'KFC의정부엔터',
#        '롯데리아당동점', '대민롯데리아공도드라이브점', '버거킹고양터미널점', '맥도날드진접DT점', '롯데리아용인보라',
#        '맥도날드서판교DT점', '한국맥도날드용인마북DT점', '한국맥도날드고양맥드라이브점', '한국맥도날드중산DT점',
#        '한길롯데리아', '버거킹수지대경GS', 'BKR버거킹광명소하마트', '한국맥도날드고양삼송DT점',
#        'BKR버거킹분당수내점', '한국맥도날드의정부금오D', '롯데리아안산한양대역', '롯데리아퇴계원',
#        '롯데리아엔제리너스경기알앤디비', '롯데리아평택안중점', '한국맥도날드안양비산에스케이', '한국맥도날드수원',
#        '한국맥도날드김포장기DT점', '꽃박람회롯데리아', '동탄케이에프씨', '케이에프씨주엽',
#        '에스피씨삼립용인강릉휴게소맥도날드', 'KFC창원상남동점', '롯데리아김해워터파크2호점',
#        '한국맥도날드진해자은D/T점', '한국맥도날드김해외동DT점', '한국맥도날드밀양DT점', '펀즈맥도날드',
#        '맥도날드양산북정DT점', '버거킹거제고현점', '제이엔디롯데리아', '롯데리아창녕점', '롯데리아고성공룡엑스포',
#        '롯데리아브랜드샵', 'KFC김해내동김해내동점', '한국맥도날드김해장유DT점', '한국맥도날드진주가좌DT점',
#        '롯데리아진주초전디아이점', 'KFC창원대동백화점점', '맥도날드김해삼계DT점', '맥도날드창원호계DT점',
#        '버거킹경남사천점', '롯데리아마산', '한국맥도날드창원내DT점', '버거킹옥포점', '버거킹마산내서삼계SK점',
#        '맥도날드창원내서DT점', '롯데리아감계점', '맥도날드창원사파점', '한국맥도날드진주칠암DT',
#        'BKR버거킹창원용호점', '롯데리아마산터미널점', '김해율하KFC', '신경주역롯데리아', '홈플러스경산롯데리아',
#        '한국맥도날드김천DT점', 'SRSKFC영남대', '한국맥도날드경주용강DT점경주용강DT점',
#        '롯데리아SK안동용상DT점', '롯데리아홈플러스경산점', '맥도날드도량DT점', 'KFC포항점', '동양식품롯데리아',
#        '맥도날드구미옥계DT점', '버거킹구미시청FS점', '한국맥도날드포항장성DT', '롯데리아경북봉화점',
#        '롯데리아영천DT점', '버거킹경북상주점', '한국맥도날드포항남부DT', 'KFC포항양덕DT점',
#        '한국맥도날드포항북부DT', '경산이마트케이에프씨', '한국맥도날드경주보문DT', 'KFC광주용봉DT',
#        '광주터미널KFC', '대영하남롯데리아하남점', '버거킹광주신용점', '롯데리아광주백운점', '맥도날드광주진월DT점',
#        '롯데리아광주풍암점', '롯데리아주월DT점주월DT점', '롯데리아대영하남', '롯데리아T.G.I.F광',
#        '한국맥도날드광주산정DT', '에스엠디롯데리아', '한국맥도날드광주월산DT점', '혜승롯데리아',
#        '롯데리아광주패밀리랜드', '에스알에스KFC광주터미널', '한국맥도날드광주쌍촌DT', 'KFC광주진월광주진월점',
#        '롯데리아광주농성DT점', '롯데리아롯데마트첨단', 'BKR버거킹광주충장점', '한국맥도날드전남대DT점',
#        '케이에프씨광주용봉DT', '한국맥도날드광주', '롯데리아상인점', '케이에프씨상인네거리', '롯데리아용산',
#        '버거킹경대병원역SK', '롯데리아북비산네거리점', '동대구역롯데리아', '버거킹지산점', '버거킹티피',
#        '롯데리아칠곡매천', '한국맥도날드대구동호DT점', '맥도날드대구교대DT점', '버거킹대구율하점',
#        '롯데리아대구월드컵대로점', '한국맥도날드동성로교보점', 'KFC상인네거리점', '에스알에스코리아KFC대',
#        'KFC대구문화동점', '롯데리아대구평리점', '롯데리아대구가창DT점', '버거킹대구칠곡3지구점',
#        '롯데리아티지아이에프', '롯데리아동대구역2호점', '한국맥도날드모다SKDT점', 'BKR버거킹대구만촌점',
#        '맥도날드용산점', '동대구롯데리아', 'BKR버거킹반야월이마트', '버거킹죽전네거리DT점', '롯데리아사월점',
#        '한국맥도날드대구희망DT', '롯데리아엔제리너스대구동', '한국맥도날드대구', '에스알에스코리아KFC영',
#        '한국맥도날드대구만촌DT', '한국맥도날드대구침산DT', '맥도날드대구황금점', '케이에프씨티',
#        '한국맥도날드대구다사DT점', '롯데리아크리스피크림도넛롯', '맥킴맥도날드', '롯데리아성서점.궁전골프',
#        '한국맥도날드대구상인DT점', '롯데리아대구성당D/T점', '한국맥도날드대구이곡DT점', '한국맥도날드대전가수원DT점',
#        '대룡롯데리아', '버거킹대전터미널SK점', '롯데리아대전버드내점', '한국맥도날드대전',
#        '롯데리아대전역사점대전역사점', '맥도날드카이스트점', 'KFC둔산이마트점', '맥도날드대전문화DT점',
#        '롯데리아와동디슬러시티', '한국맥도날드대전부사디티점', '한국맥도날드대전한남DT점', '롯데리아T.G.I.F롯',
#        '케이에프씨대전타임월드', '롯데리아엔제리너스대전', '롯데리아대전', '롯데리아대전대사드라이브',
#        '맥도날드둔산이마트점', '한국맥도날드대전센트럴에', 'KFC대전시청역', '롯데리아반석', '롯데리아엔제리너스대전시',
#        '롯데리아타임월드', '케이엘그룹/맥도날드타임', '롯데리아구포점', '맥도날드구남DT점', '한국맥도날드부산',
#        'KFC부산지오21점', '한국맥도날드부산명지DT', 'KFC신세계센텀점', '한국맥도날드부산남천DT점',
#        '한국맥도날드부산구서DT점', 'KFC이마트사상점이마트사상점', '롯데리아덕천점', '맥도날드송정DT점',
#        '맥도날드부산영도DT점', 'KFC금정이마트', 'KFC구서점', '맥도날드맥킴', '롯데리아남산정역',
#        '나뚜루롯데리아', '버거킹부산센텀오일뱅크점', '버거킹우동점', '맥도날드하단DT점', '부산동명대DT맥도날드',
#        'KFC부산장산역점', '롯데리아영도동삼점', '맥현맥도날드', '롯데리아부산재송점', '맥도날드부산엄궁DT점',
#        '롯데리아부산주례역점', '롯데리아센텀프라자빌딩점', '맥,킴한국맥도날드토곡점', '맥원맥도날드',
#        '롯데리아부산해운대좌동점', '한국맥도날드부산범전디티점', 'BKR버거킹부산광복롯데', '맥도날드만덕점',
#        '롯데리아부산명지국제신도시점', '롯데리아창원대', '케이에프씨부산지오21', '롯데리아부산전포점',
#        '한국맥도날드부산수영SK', '롯데리아부산서동점', '한국맥도날드부산온천SK', 'KFC덕천역',
#        '롯데리아크리스피크림부산', '이지케이코리아버거킹', '한국맥도날드부산엄궁디티점', '한국맥도날드부산초량DT점',
#        '한국맥도날드메가마켓점', '롯데리아해운대백병원점', '버거킹해운대신도시1호점', '롯데리아ANGELIN',
#        '한국맥도날드부산송정DT', '한국맥도날드부산다대디티점', '롯데리아올림픽공원점', '맥도날드양평SKDT점',
#        '맥도날드명지대점', 'KFC서초우성점', '맥도날드구의역점', 'KFC대림동점', '케이에프씨방배역',
#        '맥도날드한양대점', '케이에프씨홍익대매장', '롯데리아명일DT점', 'SRSKFC서소문', 'SRSKFC일원동점',
#        '맥도날드어린이대공원점', '맥도날드서초GS점', '롯데리아중화역점', 'KFC구로디지털2구로디지털2',
#        '롯데리아중랑역점', '뉴욕버거킹', 'KFC봉천역봉천역', '맥도날드강남삼성DT점', '롯데리아강남우성사거리점',
#        '버거킹석촌점', 'KFC종로점', 'KFC청계천', 'KFC대치동점', '맥도날드방학역DT점', 'KFC석촌역점',
#        'KFC광화문점', '롯데리아KKD사업본부', '한국맥도날드서울시흥DT점', '버거킹연세로점', 'KFC코엑스MALL',
#        '맥도날드쌍문DT점', '롯데리아빌라드샬롯', '롯데리아남부터미널점', '버거킹청담주성GS점', '맥도날드고척DT점',
#        '버거킹대치역점', 'KFC한리버점', '맥도날드구산점', '맥도날드서울번동DT점', '맥도날드송정역점',
#        '롯데리아길음뉴타운점', '버거킹선릉역점', '롯데리아동묘역점', '맥도날드중계역점', '맥도날드연세대점',
#        'KFC사가정점', '케이에프씨숙대입구역숙대입구역', 'KFC동대문', '맥도날드굽은다리역DT점', 'KFC학동역점',
#        '맥도날드우장산DT점', 'KFC우이동우이동점', '케이에프씨한남순천향', 'KFC코엑스몰', 'KFC광장점',
#        'KFC압구정1점', '롯데리아보문역점', '롯데리아용산전자랜드점', '롯데리아나뚜루잠실롯', '맥도날드청담DT점',
#        'KFC보라매점', '롯데리아자바커피잠실교보', 'KFC삼성동점', 'BKR버거킹대치점', 'KFC역삼점',
#        'KFC일원동점', 'KFC양재동점', 'KFC둔촌동점', 'KFC돈암동1점', '롯데리아마천점',
#        '롯데리아번동D/T점', '롯데리아군자점', '버거킹연신내역점', '롯데리아삼양사거리점', '롯데리아봉천역점',
#        '맥도날드전농점', '롯데리아송파하비오점', '롯데리아구의점', '버거킹거여역점', '맥도날드염창디티점',
#        '버거킹낙성대2점', '버거킹교대역점', '롯데리아롯데마트행당역점롯데마트행당역점', '롯데리아이수역점',
#        '케이에프씨코리아', '롯데리아명지대학점', '롯데리아롯데마트중계점롯데마트중계점', '롯데리아성대시장점',
#        '롯데리아나뚜루부문', '맥도날드서울둔촌DT점', '롯데리아롯데마트행당역점', '롯데리아고대하나스퀘어점고대하나스퀘어점',
#        '롯데리아정릉점', '버거킹길동사거리점', '버거킹양재점', '롯데리아홈플러스영등포점', '롯데리아홈플러스강서점',
#        '버거킹충무로역점', '롯데리아건대역점', '롯데리아홈플러스시흥점', '맥도날드파리공원점', '버거킹종로구청점',
#        'BKR버거킹수서점', 'BKR버거킹쌍문점', '버거킹신당역점', '버거킹고대중앙광장점', 'BKR버거킹시청역점',
#        '버거킹명일SK점', '한국맥도날드가산비즈니스센터점', '한국맥도날드등촌DT점', '버거킹장안SK점',
#        '롯데리아보네스뻬브래드', '롯데리아영주', '케이에프씨강남대로', '미아역KFC점', '한국맥도날드마리오아울렛',
#        '롯데리아엔제리너스건대시네마', '롯데리아신방화역점', '한국맥도날드신월SKD', '롯데리아강동구청D/T',
#        '맥도날드쌍문DT', '에스알에스KFC월계이마트', '롯데리아나뚜루팝', '현대빌딩롯데리아', '맥도날드중랑점',
#        '버거킹신림역점', '맥도날드종로3가점', '맥도날드과학기술대점', '롯데리아미아삼거리점', '버거킹구로구청점',
#        '맥도날드위례신도시점', '한국맥도날드강남삼성DT점', 'KFC우장산역매장', 'KFC보라매매장',
#        '맥도날드성균관대점', 'BKR버거킹문정점', 'BKR버거킹쌍문SK점', '맥도날드서울동묘역점', '롯데리아시흥중앙점',
#        '롯데리아길동점', '버거킹가재울뉴타운점', 'BKR버거킹송파구청점', 'BKR버거킹목동이마트점', '롯데리아고덕역점',
#        '맥도날드장안사거리점', '한국맥도날드강남2호', '한국맥도날드은평이마트', '맥도날드이수점', '맥도날드숭실대점',
#        '맥도날드서울상암DMC점', '맥도날드가산디지털점가산디지털점', '양평sk맥도날드', '롯데리아노원역점',
#        '에스알에스KFC압구정1', '롯데리아T.G.I.F잠', '맥도날드석촌역점', '맥도날드삼선점', 'SKfC',
#        '맥도날드신사역점', '롯데리아장안사거리점', '맥도날드서초뱅뱅점', '롯데리아크리스피크림SK', '롯데리아구의역점',
#        '맥도날드중계점', '롯데리아상일동상일동점', '에스케이에프씨', '롯데리아보네스삐브레드종',
#        '한국맥도날드상계DT점상계DT점', '한국로날드맥도날드하우스', '롯데리아TGIF사업부', '한국맥도날드신도림디큐브',
#        'BKR버거킹건대역점', '로날드맥도날드하우스', '버거킹연희점', '한국맥도날드미아DT점',
#        '롯데리아G/S마트상계점', '롯데리아구로가산점', '롯데리아혜화점', '롯데리아구로시장점', '롯데리아엔제리너스커피',
#        '버거킹목동역점', '버거킹청담점', '롯데리아신천점', '롯데리아시흥', '롯데리아합정점', '롯데리아사당점',
#        '맥도날드신천점', '버거킹사당역점', '케이에프씨석촌역', '월계이마트KFC', '에스알에스케이에프씨',
#        '롯데리아홈플러스울산중구', '한국맥도날드울산삼산DT점', '롯데리아울산대학점', '맥도날드울산메가마켓점',
#        '맥도날드옥현점', '롯데리아울산터미널점', '맥도날드울산일산DT점', '롯데리아정자해변점', '버거킹울산무거점',
#        '롯데리아울산반구점', '롯데리아울산온산점', '롯데리아울산구영점', '맥킴맥도날드울산', '버거킹울산우정에스케이',
#        '한국맥도날드울산호계SK', '한국맥도날드삼산로D', '롯데리아홈플러스울산', '케이에프씨계산동',
#        '롯데리아인천당하점인천당하점', 'SRSKFC인천공항랜드', '한국맥도날드계산DT점', 'KFC동인천이마트점',
#        '버거킹인천송도SK점', 'KFC인천청라점', '맥도날드송도지점', '롯데리아홈플러스송도', 'KFC인천공항랜드2',
#        '롯데리아인천영종하늘도시점', '한국맥도날드인천', '롯데리아공항신도시점', 'BKR버거킹인천공항1점',
#        '롯데리아청라경서점', '버거킹인천계양구청점', '한국맥도날드문학DT', '에스알에스KFC코리아',
#        '롯데리아인천삼산점', '롯데리아인천공항탑승동점', '롯데리아삼산', '한국맥도날드인천구산DT', '롯데리아용현점2',
#        '청라케이에프씨', '한국맥도날드인천구월DT', '에스알에스코리아KFC인', '버거킹인천연수점', '롯데리아나뚜루1',
#        'BKR버거킹문학야구장점', '여천롯데마트롯데리아', '맥도날드순천조례DT점', '한국맥도날드목포남악DT점',
#        '롯데리아순천', '버거킹광양중동점', '한국맥도날드여수학동DT점', '롯데리아목포용해점', '맥도날드여수학동DT점',
#        '롯데리아담양점', '롯데리아디오션', '롯데리아벌교점', '롯데리아담양메타점', '담양롯데리아메타점',
#        '롯데리아고흥', '한국맥도날드목포석현DT', '한국맥도날드여수학동DT', '한국맥도날드순천덕암DT점',
#        '롯데리아구례중앙', 'KFC순천연향점', '한국맥도날드광양DT점', '버거킹전남도청점', '롯데리아홈플러스',
#        '롯데리아여수중앙점', '시몬롯데리아', '버거킹정읍중앙점', '케이에프씨엔아이', '롯데리아익산배산점',
#        '맥도날드전주평화DT점', '한국맥도날드전주덕진디티점', '롯데리아전주터미널점', '한국맥도날드이마트군산점',
#        '롯데리아전주메가월드점', '버거킹전주중앙점', '롯데리아무주', '한일알이에스롯데리아', '롯데리아김제점',
#        '롯데리아조촌DT점', '한국맥도날드전주디티점', '롯데리아평화점', '맥도날드익산영등DT점', '롯데리아완주봉동점',
#        '맥도날드전북정읍DT점', '롯데리아T.G.I.F전', '호영롯데리아', '버거킹서신대광SK점',
#        '한국맥도날드익산영등DT', '롯데리아수송점', '롯데리아남원점', '한일알이에스롯데리아수송', '롯데리아전주도청점',
#        '한국맥도날드제주공항디티점', '롯데리아제주항공우주박물관점', '맥도날드일도DT점', '롯데리아제주표선해변점',
#        '한국맥도날드제주중문DT점', '한국맥도날드제주일도DT점', '한국맥도날드제주월드컵스타디움DT점',
#        '한국맥도날드제주도남DT점', '롯데리아롯데마트천안점', '코레일유통롯데리아', '한국맥도날드충남보령DT점',
#        '맥도날드당진DT점', '우창롯데리아부여점', '롯데리아서산휴게소목포방면', '롯데리아천안통정점',
#        '맥도날드천안쌍용SKDT점', '롯데리아충남도청점', '롯데리아보령동대점', '롯데리아이인휴게소천안방면',
#        '버거킹서산호수공원점', '백광소재서산휴게소롯데리아', '롯데리아당진신평점', '이인상휴게소롯데리아',
#        '한국맥도날드천안', 'KFC천안쌍용점', '한국맥도날드충남홍성DT점', '천안통정롯데리아',
#        '선앤드진롯데리아독립기념관점', 'SRSKFC청주쥬네쓰점', '롯데리아충주용산점', '롯데리아라이스',
#        '롯데리아청주강내점', '맥도날드청주율량GSDT점청주율량GSDT점', '버거킹청주오송점', '롯데리아오창2산단점',
#        '맥도날드율량지에스', '롯데리아청주금천점', '롯데리아칠금점', '롯데리아죽암휴게소하DT'], dtype=object)

# %%
# 브랜드 파생변수 만들기/예외처리
for bname in burger:
    df.loc[df["상호명_대문자"].str.contains(bname),"브랜드"] = bname

df.loc[df["상호명_대문자"].str.contains("케이에프씨"),"브랜드"] = "KFC"
df.loc[df["상호명_대문자"].str.contains("멕도날드"),"브랜드"] = "맥도날드"

# %%
df[["상호명", "브랜드"]]
# Out:
#       상권업종대분류명           상호명                               도로명주소          경도  \
# 2699        음식           버거킹          강원도 홍천군 서면 한치골길 262, (팔봉리)  127.687273
# 3162        음식          롯데리아        강원도 원주시 지정면 오크밸리2길 58, (월송리)  127.808946
# 6156        음식     케이에프씨원주단계             강원도 원주시 북원로 2266, (단계동)  127.934373
# 8195        음식          맥도날드            강원도 속초시 동해대로 4118, (조양동)  128.583904
# 8275        음식          맥도날드             강원도 원주시 서원대로 154, (단계동)  127.928180
# ...        ...           ...                                 ...         ...
# 72250       음식          롯데리아       충청북도 충주시 수안보면 주정산로 183, (온천리)  127.975854
# 73850       음식          롯데리아        충청북도 청주시 서원구 내수동로 116, (사창동)  127.460250
# 74844       음식          롯데리아          충청북도 제천시 풍양로13길 5, (중앙로1가)  128.210943
# 78041       음식           버거킹        충청북도 음성군 맹동면 대하2가길 11, (두성리)  127.542769
# 85321       음식  롯데리아죽암휴게소하DT  충청북도 청주시 서원구 현도면 경부고속도로 289, (선동리)  127.429193
#
#               위도   시도명 시군구명       상호명_대문자   브랜드
# 2699   37.652324   강원도  홍천군           버거킹   버거킹
# 3162   37.407858   강원도  원주시          롯데리아  롯데리아
# 6156   37.348017   강원도  원주시     케이에프씨원주단계   KFC
# 8195   38.189882   강원도  속초시          맥도날드  맥도날드
# 8275   37.344175   강원도  원주시          맥도날드  맥도날드
# ...          ...   ...  ...           ...   ...
# 72250  36.849507  충청북도  충주시          롯데리아  롯데리아
# 73850  36.633746  충청북도  청주시          롯데리아  롯데리아
# 74844  37.137848  충청북도  제천시          롯데리아  롯데리아
# 78041  36.907964  충청북도  음성군           버거킹   버거킹
# 85321  36.486964  충청북도  청주시  롯데리아죽암휴게소하DT  롯데리아
#
# [2103 rows x 9 columns]

# %%
# 표만들기
df["브랜드"].value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot: >

# %%
# 전국 시도별 상호수와 버거지수
df_skorea = df.groupby(["시도명","브랜드"])["상호명"].count().unstack().fillna(0).astype(int)
df_skorea["합계"] = df_skorea.sum(axis=1)
df_skorea
# Out:
# 브랜드      KFC  롯데리아  맥도날드  버거킹   합계
# 시도명
# 강원도       10    39    11   11   71
# 경기도       78   231   103   97  509
# 경상남도       7    64    33   22  126
# 경상북도       9    48    16   22   95
# 광주광역시      9    34    14   10   67
# 대구광역시     13    44    30   19  106
# 대전광역시     10    40    17   19   86
# 부산광역시     13    51    55   21  140
# 서울특별시     94   128   100  117  439
# 세종특별자치시    1     8     0    2   11
# 울산광역시      1    26    14    9   50
# 인천광역시     17    48    20   24  109
# 전라남도       2    44    14    5   65
# 전라북도       3    44    13   11   71
# 제주특별자치도    1    14    13    2   30
# 충청남도       3    48    11    6   68
# 충청북도       5    38    10    7   60

# %%
# 버거지수
df_skorea["버거지수"] = (df_skorea["KFC"] + df_skorea["버거킹"] + df_skorea["맥도날드"]) / df_skorea["롯데리아"]
df_skorea
# Out:
# 브랜드      KFC  롯데리아  맥도날드  버거킹   합계      버거지수
# 시도명
# 강원도       10    39    11   11   71  0.820513
# 경기도       78   231   103   97  509  1.203463
# 경상남도       7    64    33   22  126  0.968750
# 경상북도       9    48    16   22   95  0.979167
# 광주광역시      9    34    14   10   67  0.970588
# 대구광역시     13    44    30   19  106  1.409091
# 대전광역시     10    40    17   19   86  1.150000
# 부산광역시     13    51    55   21  140  1.745098
# 서울특별시     94   128   100  117  439  2.429688
# 세종특별자치시    1     8     0    2   11  0.375000
# 울산광역시      1    26    14    9   50  0.923077
# 인천광역시     17    48    20   24  109  1.270833
# 전라남도       2    44    14    5   65  0.477273
# 전라북도       3    44    13   11   71  0.613636
# 제주특별자치도    1    14    13    2   30  1.142857
# 충청남도       3    48    11    6   68  0.416667
# 충청북도       5    38    10    7   60  0.578947
